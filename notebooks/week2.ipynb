# %%
import pandas as pd

# %%
data = [100, 102, 104]

# %%
series = pd.Series(data, index=["a", "b", "c"])

# %%
print(series.loc["a"])
# Out:
# 100

# %%
df = pd.read_csv('../data/ucsc_genes.txt', sep='\t')

print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#    #bin          name chrom strand   txStart     txEnd  cdsStart    cdsEnd  \
# 0     0     NM_207014  chr1      -  67075873  67163127  67075923  67163102
# 1     0     NM_024763  chr1      -  67051159  67163127  67052400  67163102
# 2     1  NM_001042681  chr1      -   8335050   8800286   8337733   8638943
# 3     1     NM_012102  chr1      -   8335050   8800286   8337733   8638943
# 4     1  NM_001042682  chr1      -   8335050   8406479   8337733   8346780
#
#    exonCount                                         exonStarts  \
# 0         10  67075873,67078739,67085754,67100417,67109640,6...
# 1         17  67051159,67060631,67065090,67066082,67071855,6...
# 2         23  8335050,8338065,8338746,8340842,8342410,834275...
# 3         24  8335050,8338065,8338746,8340842,8342410,834275...
# 4         13  8335050,8338065,8338746,8340842,8342410,834275...
#
#                                             exonEnds  score  name2  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119715 entries, 0 to 119714
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   #chrom        119715 non-null  object
#  1   chromStart    119715 non-null  int64
#  2   chromEnd      119715 non-null  int64
#  3   name          119715 non-null  object
#  4   score         119715 non-null  int64
#  5   strand        119715 non-null  object
#  6   thickStart    119715 non-null  int64
#  7   thickEnd      119714 non-null  float64
#  8   reserved      119714 non-null  float64
#  9   blockCount    119714 non-null  float64
#  10  blockSizes    119714 non-null  object
#  11  chromStarts   119714 non-null  object
#  12  name2         119714 non-null  object
#  13  cdsStartStat  119714 non-null  object
#  14  cdsEndStat    119714 non-null  object
#  15  exonFrames    119714 non-null  object
#  16  type          0 non-null       float64
# ...

# %%
chr17_genes = df[df['#chrom'] == 'chr17']

print(f"Genes on chromosome 17: {len(chr17_genes)}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '#chrom'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ...

# %%
print(df.columns.tolist())
# Out:
# ['#bin', 'name', 'chrom', 'strand', 'txStart', 'txEnd', 'cdsStart', 'cdsEnd', 'exonCount', 'exonStarts', 'exonEnds', 'score', 'name2', 'cdsStartStat', 'cdsEndStat', 'exonFrames']

# %%
chr17_genes = df[df['chrom'] == 'chr17']

print(f"\nGenes on chromosome 17: {len(chr17_genes)}")
# Out:
# Genes on chromosome 17: 3943

# %%
print("Unique chromosome values:")
print(df['chrom'].unique())

# Check first 10 rows to see the data
print("\nFirst 10 rows of chromosome column:")
# Out:
# Unique chromosome values:
# ['chr1' 'chr2' 'chr3' 'chr4' 'chr5' 'chr6' 'chr7' 'chr8' 'chr9' 'chrM'
#  'chrX' 'chrY' 'chr10' 'chr11' 'chr12' 'chr13' 'chr14' 'chr15' 'chr16'
#  'chr17' 'chr18' 'chr19' 'chr20' 'chr21' 'chr22' 'chr1_random'
#  'chr2_random' 'chr3_random' 'chr4_random' 'chr5_random' 'chr6_random'
#  'chr7_random' 'chr8_random' 'chr9_random' 'chrX_random' 'chr13_random'
#  'chr15_random' 'chr16_random' 'chr17_random' 'chr19_random'
#  'chr21_random' 'chr22_random' 'chr5_h2_hap1' 'chr22_h2_hap1'
#  'chr6_cox_hap1' 'chr6_qbl_hap2']
#
# First 10 rows of chromosome column:
