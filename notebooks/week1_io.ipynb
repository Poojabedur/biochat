# %%
from Bio import SeqIO

# %%
record = SeqIO.read("../data/sequence.gb", "genbank")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 record = SeqIO.read("../data/sequence.gb", "genbank")
#
# File ~/Library/Python/3.9/lib/python/site-packages/Bio/SeqIO/__init__.py:687, in read(handle, format, alphabet)
#     685         pass
#     686 else:
# --> 687     with parse(handle, format, alphabet) as records:
#     688         try:
#     689             record = next(records)
#
# File ~/Library/Python/3.9/lib/python/site-packages/Bio/SeqIO/__init__.py:626, in parse(handle, format, alphabet)
#     624 iterator_generator = _FormatToIterator.get(format)
#     625 if iterator_generator:
# --> 626     return iterator_generator(handle)
#     627 if format in AlignIO._FormatToIterator:
#     628     # Use Bio.AlignIO to read in the alignments
#     629     return (r for alignment in AlignIO.parse(handle, format) for r in alignment)
#
# ...
