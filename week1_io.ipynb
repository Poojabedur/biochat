# %%
from Bio import SeqIO

# %%
record = SeqIO.read("data/sequence.gb", "genbank")

# %%
print(f"record name {record.name}")
# Out:
# record name NM_007294

# %%
print(f"length: {len(record.seq)}")
# Out:
# length: 7088

# %%
print("First 10 features")
# Out:
# First 10 features

# %%
for i, feature in enumerate(record.features[:10]):
    print(f"{i+1}. Type: {feature.type}, Location: {feature.location}")
# Out:
# 1. Type: source, Location: [0:7088](+)
# 2. Type: gene, Location: [0:7088](+)
# 3. Type: exon, Location: [0:94](+)
# 4. Type: misc_feature, Location: [89:92](+)
# 5. Type: exon, Location: [94:193](+)
# 6. Type: CDS, Location: [113:5705](+)
# 7. Type: misc_feature, Location: [113:116](+)
# 8. Type: misc_feature, Location: [452:455](+)
# 9. Type: misc_feature, Location: [800:923](+)
# 10. Type: misc_feature, Location: [1028:1127](+)
